# %%
from khaiii import KhaiiiApi
try:
    import ujson
except ImportError:
    import json

# %%
api = KhaiiiApi()
api.open()

# %%
with open('./data/2017_03.json') as f:
    data = json.load(f)

# %%
data[0]
# Out:
# {'date': '2017-03-01',
#  'text': '플레이어 이동시키기 플레이어 닫기\n\n<앵커>\n\n\n\n98년 전 3월 1일 태극기를 들고 거리로 나서서 독립을 외치던 우리의 할아버지, 할머니들이 오늘(1일) 서울 한복판이 이렇게 둘로 갈라진 모습을 보면 뭐라고 생각하실까요? 탄핵 찬성과 반대, 각각 목소리를 높인 집회 참가자들 머리 위로는 비가 내렸고, 날씨는 을씨년스러웠습니다.\n\n\n\n먼저 권란 기자가 오늘 집회 상황 종합했습니다.\n\n\n\n<기자>\n\n\n\n광화문 광장과 맞닿은 세종대로 남쪽에서 먼저 탄핵 반대 집회가 시작됐습니다.\n\n\n\n서울광장에 이어 숭례문까지 태극기를 든 참가자들로 꽉 찼습니다.\n\n\n\n대형 태극기에다 성조기까지 등장했고, 고 박정희 전 대통령의 얼굴이 그려진 깃발도 배포됐습니다.\n\n\n\n참가자들은 헌재의 탄핵 결정을 앞두고 목청 높여 탄핵에 반대했습니다.\n\n\n\n \n\n\n\n집회 시작 네 시간쯤 뒤부터는 탄핵 반대 집회 측으로선 처음으로 청와대 방향 행진을 시작했습니다.\n\n\n\n헌재와 도심 등 5개 경로로 행진을 이어갔습니다.\n\n\n\n탄핵 반대 집회가 끝나갈 무렵인 오후 5시쯤부터는 탄핵 찬성 집회가 세종대로 북쪽 광화문광장에서 열렸습니다.\n\n\n\n충돌을 우려해 경찰이 차벽으로 양측을 막아선 가운데, 촛불을 든 시민들은 헌재의 탄핵 인용 결정을 촉구하며 목소리를 높였습니다.\n\n\n\n \n\n\n\n특히 3.1절을 맞아 위안부 피해자 이용수 할머니가 무대에 올라 아리랑을 부르자, 참가자 모두 따라 부르기도 했습니다.\n\n\n\n \n\n\n\n박근혜 대통령 탄핵 여부가 결정되는 운명의 3월 첫날에 서울 도심 광장을 둘로 나눈 대규모 집회여서 충돌이 걱정됐지만 다행히 아직 불상사는 없는 상황입니다.\n\n\n\n(영상취재 : 신진수·김성일·박진호, 영상편집 : 윤선영)',
#  'title': '대통령 운명 결정할 3월…탄핵 찬반에 둘로 나뉜 3·1절'}

# %%
for words in api.analyze(data[0]['text']):
    for morph in words.morphs:
        print(morph.lex, morph.tag)
# Out:
# 플레이어 NNG
# 이동 NNG
# 시키 XSV
# 기 ETN
# 플레이어 NNG
# 닫 VV
# 기 ETN
# < SS
# 앵커 NNG
# > SS
# 98 SN
# 년 NNB
# 전 NNG
# 3 SN
# 월 NNB
# 1 SN
# 일 NNB
# 태극기 NNG
# 를 JKO
# 들 VV
# 고 EC
# 거리 NNG
# 로 JKB
# 나서 VV
# 어서 EC
# 독립 NNG
# 을 JKO
# 외치 VV
# 던 ETM
# 우리 NP
# 의 JKG
# 할아버지 NNG
# , SP
# 할머니 NNG
# 들 XSN
# 이 JKS
# 오늘 NNG
# ( SS
# 1 SN
# 일 NNB
# ) SS
# 서울 NNP
# 한 XPN
# 복판 NNG
# 이 JKS
# 이렇 VA
# 게 EC
# 둘 NR
# 로 JKB
# 갈라지 VV
# ㄴ ETM
# 모습 NNG
# 을 JKO
# 보 VV
# 면 EC
# 뭐 NP
# 이 VCP
# 라고 EC
# 생각 NNG
# 하 XSV
# 시 EP
# ㄹ까요 EF
# ? SF
# 탄핵 NNG
# 찬성 NNG
# 과 JC
# 반대 NNG
# , SP
# 각각 MAG
# 목소리 NNG
# 를 JKO
# 높이 VV
# ㄴ ETM
# 집회 NNG
# 참가자 NNG
# 들 XSN
# 머리 NNG
# 위 NNG
# 로 JKB
# 는 JX
# 비 NNG
# 가 JKS
# 내리 VV
# 었 EP
# 고 EC
# , SP
# 날씨 NNG
# 는 JX
# 을씨년스럽 VA
# 었 EP
# 습니다 EF
# . SF
# 먼저 MAG
# 권란 NNP
# 기자 NNG
# 가 JKS
# 오늘 NNG
# 집회 NNG
# 상황 NNG
# 종합 NNG
# 하 XSV
# 였 EP
# 습니다 EF
# . SF
# < SS
# 기 NNG
# 자 NNP
# > SS
# 광화문 NNP
# 광장 NNG
# 과 JC
# 맞닿 VV
# 은 ETM
# 세종대 NNP
# 로 JKB
# 남쪽 NNG
# 에서 JKB
# 먼저 MAG
# 탄핵 NNG
# 반대 NNG
# 집회 NNG
# 가 JKS
# 시작 NNG
# 되 XSV
# 었 EP
# 습니다 EF
# . SF
# 서울광 NNP
# 장 NNG
# 에 JKB
# 잇 VV
# 어 EC
# 숭례문 NNP
# 까지 JX
# 태극기 NNG
# 를 JKO
# 들 VV
# ㄴ ETM
# 참가자 NNG
# 들 XSN
# 로 JKB
# 꽉 MAG
# 차 VV
# 았 EP
# 습니다 EF
# . SF
# 대 NNG
# 형 XSN
# 태극기 NNG
# 에다 JKB
# 성조기 NNG
# 까지 JX
# 등장 NNG
# 하 XSV
# 였 EP
# 고 EC
# , SP
# 고 MM
# 박정희 NNP
# 전 MM
# 대통령 NNG
# 의 JKG
# 얼굴 NNG
# 이 JKS
# 그리 VV
# 어 EC
# 지 VX
# ㄴ ETM
# 깃발 NNG
# 도 JX
# 배포 NNG
# 되 XSV
# 었 EP
# 습니다 EF
# . SF
# 참가자 NNG
# 들 XSN
# 은 JX
# 헌재 NNG
# 의 JKG
# 탄핵 NNG
# 결정 NNG
# 을 JKO
# 앞두 VV
# 고 EC
# 목청 NNG
# 높이 VV
# 어 EC
# 탄핵 NNG
# 에 JKB
# 반대 NNG
# 하 XSV
# 였 EP
# 습니다 EF
# . SF
# 집회 NNG
# 시작 NNG
# 네 MM
# 시간 NNG
# 쯤 XSN
# 뒤 NNG
# 부터 JX
# 는 JX
# 탄핵 NNG
# 반대 NNG
# 집회 NNG
# 측 NNB
# 으로서 JKB
# ㄴ JX
# 처음 NNG
# 으로 JKB
# 청와대 NNP
# 방향 NNG
# 행진 NNG
# 을 JKO
# 시작 NNG
# 하 XSV
# 였 EP
# 습니다 EF
# . SF
# 헌재 NNG
# 와 JC
# 도심 NNG
# 등 NNB
# 5 SN
# 개 NNB
# 경로 NNG
# 로 JKB
# 행진 NNG
# 을 JKO
# 잇 VV
# 어 EC
# 가 VX
# 았 EP
# 습니다 EF
# . SF
# 탄핵 NNG
# 반대 NNG
# 집회 NNG
# 가 JKS
# 끝나 VV
# 아 EC
# 가 VX
# ㄹ ETM
# 무렵 NNB
# 이 VCP
# ㄴ ETM
# 오후 NNG
# 5 SN
# 시 NNB
# 쯤 NNG
# 부터 JX
# 는 JX
# 탄핵 NNG
# 찬성 NNG
# 집회 NNG
# 가 JKS
# 세종대 NNP
# 로 JKB
# 북쪽 NNG
# 광화문광 NNP
# 장 NNG
# 에서 JKB
# 열리 VV
# 었 EP
# 습니다 EF
# . SF
# 충돌 NNG
# 을 JKO
# 우려 NNG
# 하 XSV
# 여 EC
# 경찰 NNG
# 이 JKS
# 차벽 NNG
# 으로 JKB
# 양측 NNG
# 을 JKO
# 막아 VV
# 서 EC
# ㄴ JX
# 가운데 NNG
# , SP
# 촛불 NNG
# 을 JKO
# 들 VV
# ㄴ ETM
# 시민 NNG
# 들 XSN
# 은 JX
# 헌재 NNG
# 의 JKG
# 탄핵 NNG
# 인용 NNG
# 결정 NNG
# 을 JKO
# 촉구 NNG
# 하 XSV
# 며 EC
# 목소리 NNG
# 를 JKO
# 높이 VV
# 었 EP
# 습니다 EF
# . SF
# 특히 MAG
# 3 SN
# . SP
# 1 SN
# 절 NNG
# 을 JKO
# 맞 VV
# 아 EC
# 위안부 NNG
# 피해자 NNG
# 이용수 NNP
# 할머니 NNG
# 가 JKS
# 무대 NNG
# 에 JKB
# 오르 VV
# 아 EC
# 아리랑 NNP
# 을 JKO
# 부르 VV
# 자 EC
# , SP
# 참가자 NNG
# 모두 MAG
# 따르 VV
# 아 EC
# 부르 VV
# 기 ETN
# 도 JX
# 하 VX
# 였 EP
# 습니다 EF
# . SF
# 박근혜 NNP
# 대통령 NNG
# 탄핵 NNG
# 여부 NNG
# 가 JKS
# 결정 NNG
# 되 XSV
# 는 ETM
# 운명 NNG
# 의 JKG
# 3 SN
# 월 NNB
# 첫날 NNG
# 에 JKB
# 서울 NNP
# 도심 NNG
# 광장 NNG
# 을 JKO
# 둘 NR
# 로 JKB
# 나누 VV
# ㄴ ETM
# 대 XPN
# 규모 NNG
# 집회 NNG
# 이 VCP
# 어서 EC
# 충돌 NNG
# 이 JKS
# 걱정 NNG
# 되 XSV
# 었 EP
# 지만 EC
# 다행히 MAG
# 아직 MAG
# 불상사 NNG
# 는 JX
# 없 VA
# 는 ETM
# 상황 NNG
# 이 VCP
# ㅂ니다 EF
# . SF
# ( SS
# 영상 NNG
# 취재 NNG
# : SP
# 신진수 NNP
# · SP
# 김성일 NNP
# · SP
# 박진호 NNP
# , SP
# 영상편집 NNG
# : SP
# 윤선영 NNP
# ) SS

# %%
tags = set(['NNG', 'NNP', 'VA', 'VV'])
article_list = []
for i, article in enumerate(data):
    if i % 1000 == 0:
        print(i)
    
    text = article['text'].strip()
    if len(text) > 10:
        words_list = []
        for words in api.analyze(text):
            for morph in words.morphs:
                if morph.tag in tags and len(morph.lex) > 1:
                    words_list.append(morph.lex)

        article_list.append(words_list)
        
        if len(article_list) == 10000:
            break
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000

# %%
from collections import Counter

word_count = Counter()

for words_list in article_list:
    word_count.update(words_list)
    
voca = [w for w, freq in word_count.most_common(10000)]
word2id = {w: i for i, w in enumerate(voca)}

article_list_ = []
for words_list in article_list:
    words = [w for w in words_list if w in word2id]
    if len(words) >= 5:
        article_list_.append(words)

# %%
import numpy as np
from sklearn.preprocessing import normalize

tdm = np.zeros((len(article_list_), len(voca)), dtype=np.float32)
for i, words in enumerate(article_list_):
    for word in words:
        try:
            tdm[i, word2id[word]] += 1
        except KeyError:
            pass
        
normalize(tdm, copy=False)
# Out:
# array([[0.45749572, 0.        , 0.10166571, ..., 0.        , 0.        ,
#         0.        ],
#        [0.33686078, 0.        , 0.42107597, ..., 0.        , 0.        ,
#         0.        ],
#        [0.3117688 , 0.45944875, 0.36099544, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.04291411, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.02834101, 0.08502303, 0.05668202, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ]], dtype=float32)

# %%
from sklearn.decomposition import NMF

K = 10
nmf = NMF(n_components=K)
W = nmf.fit_transform(tdm)
H = nmf.components_

# %%
for k in range(K):
    print(f"{k}th topic")
    for i in H[k].argsort()[::-1][:20]:
        print(voca[i], end=' ')
    print()
# Out:
# 0th topic
# 대통령 박 박근혜 탄핵 하 되 주장 있 없 말 받 변호사 대하 청와대 대리인단 사람 정치 최순실 보 재단
# 1th topic
# 하 대표 있 대하 되 국민 말 지사 당 의원 없 정치 대선 후보 보 한국당 민주당 자유 문 주당
# 2th topic
# 방송 사고 물 고 등장 부부 행복 스타 딸 사탕 웃음줘 켈리 지사 대구 출연 안희정 이 차량 중대본 세
# 3th topic
# 집회 태극기 촛불 탄핵 행진 반대 광장 오후 경찰 시민 이날 참석 참가자 퇴진 행동 광화문 청와대 절 들 단체
# 4th topic
# 시간 전 하 지원 시 대선 간 스 드 불출마 보통사람 일 한국 기 정부 크 서 인상 금리 주택
# 5th topic
# 서울 박근혜 기자 열리 오후 퇴진 촛불 탄핵 장 촉구 뉴스 날 광화문광 집회 동 행 범국민 광장 광화문 참가자
# 6th topic
# 탄핵 서울 기각 국민 위하 반대 본부 운동 총궐기 열리 태극기 집회 대통령 절 뉴스 주최 오후 탄기국 기자 취재단
# 7th topic
# 수사 특검 검찰 팀 국회 대하 연장 박 특별 우 검사 최순실 박영수 결과 하 사건 혐의 수석 상정 조사
# 8th topic
# 탄핵 헌재 헌법 심판 재판관 선고 재판소 대행 권한 결정 국회 인용 대하 평의 이정미 있 변론 의견 최종 기자
# 9th topic
# ź í Ŕ Ą ş ĚľĽŔ đš Ç ö Ă Á ŔüšŽ ż ě ú ° Ł ç Ż Č
